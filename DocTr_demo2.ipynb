# %%
# !pip install -e git+https://github.com/mindee/doctr.git#egg=python-doctr[torch]
# Out:
# DEPRECATION: git+https://github.com/mindee/doctr.git#egg=python-doctr[torch] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Obtaining python-doctr[torch] from git+https://github.com/mindee/doctr.git#egg=python-doctr[torch]
#   Cloning https://github.com/mindee/doctr.git to ./src/python-doctr
#   Running command git clone --filter=blob:none --quiet https://github.com/mindee/doctr.git /content/src/python-doctr
#   Resolved https://github.com/mindee/doctr.git to commit 99eb5a33aaab2a7a0e037963810c7304a9cbd956
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...

# %%
import os
os.environ['USE_TORCH']='1'

import matplotlib.pyplot as plt
# %matplotlib inline
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
model=ocr_predictor(pretrained=True)
# Out:
# ...
#   0%|          | 0/63286381 [00:00<?, ?it/s]

# %%
hand_written=DocumentFile.from_images('/content/drive/MyDrive/datasets/image/handWritten.png')
tax_invoice=DocumentFile.from_images('/content/drive/MyDrive/datasets/image/tax_invoice.jpg')
insta=DocumentFile.from_images('/content/drive/MyDrive/datasets/image/Instagram.jpg')
#pdf=DocumentFile.from_pdf('/content/PO_Sample1[1].pdf')

# %%
nike=DocumentFile.from_images('/content/drive/MyDrive/datasets/image/Nike.jpg')
godrej=DocumentFile.from_images('/content/drive/MyDrive/datasets/image/Godrej.jpg')

# %%
tax_inv_result=model(tax_invoice)

# %%
insta_result=model(insta)

# %%
insta_result.show()

# %%
godrej_result=model(godrej)
godrej_result.show()

# %%
import matplotlib.pyplot as plt

# Assuming `result1.synthesize()` returns a list of images (numpy arrays)
synthetic_pages_insta = insta_result.synthesize()

# Print image array shape and datatype
print(synthetic_pages_insta[0].shape, synthetic_pages_insta[0].dtype)

# Display the image using imshow to verify content
plt.figure(figsize=(10, 20))
plt.imshow(synthetic_pages_insta[0])
plt.axis('off')
plt.savefig('synthetic_image_insta.png', bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# ...

# %%
print(type(synthetic_pages_insta[0]))  # Should be numpy.ndarray or similar
print(synthetic_pages_insta[0].shape)   # Should show dimensions like (height, width, channels)
# Out:
# <class 'numpy.ndarray'>
# (1146, 898, 3)

# %%
# Assuming `result1.synthesize()` returns a list of images (numpy arrays)
synthetic_pages_godrej = godrej_result.synthesize()

# Print image array shape and datatype
print(synthetic_pages_godrej[0].shape, synthetic_pages_godrej[0].dtype)

# Display the image using imshow to verify content
plt.figure(figsize=(10, 20))
plt.imshow(synthetic_pages_godrej[0])
plt.axis('off')
plt.savefig('synthetic_image_godrej.png', bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# ...

# %%
# !pip install pyzbar

# %%
sudo apt-get install libzbar0 libzbar-dev
# Out:
#   File "<ipython-input-46-7f9421d1c4cf>", line 1
#     sudo apt-get install libzbar0 libzbar-dev
#          ^
# SyntaxError: invalid syntax

# %%
import cv2
import pyzbar.pyzbar as pyzbar

# Load the image
image = cv2.imread('/content/drive/MyDrive/datasets/image/Godrej.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect the QR code
qr_code = pyzbar.decode(gray_image)

# Print the decoded data
for barcode in qr_code:
    print('Decoded data:', barcode.data.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-ff2ff01a2d85> in <cell line: 2>()
#       1 import cv2
# ----> 2 import pyzbar.pyzbar as pyzbar
#       3
#       4 # Load the image
#       5 image = cv2.imread('/content/drive/MyDrive/datasets/image/Godrej.jpg')
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/pyzbar.py in <module>
#       5 from .locations import bounding_box, convex_hull, Point, Rect
#       6 from .pyzbar_error import PyZbarError
# ----> 7 from .wrapper import (
#       8     zbar_image_scanner_set_config,
#       9     zbar_image_scanner_create, zbar_image_scanner_destroy,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in <module>
#     149
#     150
# --> 151 zbar_version = zbar_function(
#     152     'zbar_version',
#     153     c_int,
#
# ...

# %%
os.environ['PATH'] += r"C:\Users\bokke\ZBar"
import pyzbar.pyzbar as pyzbar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-5c84ea760182> in <cell line: 2>()
#       1 os.environ['PATH'] += r"C:\Users\bokke\ZBar"
# ----> 2 import pyzbar.pyzbar as pyzbar
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/pyzbar.py in <module>
#       5 from .locations import bounding_box, convex_hull, Point, Rect
#       6 from .pyzbar_error import PyZbarError
# ----> 7 from .wrapper import (
#       8     zbar_image_scanner_set_config,
#       9     zbar_image_scanner_create, zbar_image_scanner_destroy,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in <module>
#     149
#     150
# --> 151 zbar_version = zbar_function(
#     152     'zbar_version',
#     153     c_int,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in zbar_function(fname, restype, *args)
#     146     """
# ...

# %%
import cv2
os.environ['PATH'] += r"C:\Users\bokke\ZBar"
import pyzbar.pyzbar as pyzbar

# Load the image
image = cv2.imread(r'C:\path\to\your\image.jpg')  # Use raw string (r'') to avoid escaping backslashes

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect the QR code
qr_codes = pyzbar.decode(gray_image)

# Print the decoded data
for qr_code in qr_codes:
    print('Decoded data:', qr_code.data.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-8b93ecf77fec> in <cell line: 3>()
#       1 import cv2
#       2 os.environ['PATH'] += r"C:\Users\bokke\ZBar"
# ----> 3 import pyzbar.pyzbar as pyzbar
#       4
#       5 # Load the image
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/pyzbar.py in <module>
#       5 from .locations import bounding_box, convex_hull, Point, Rect
#       6 from .pyzbar_error import PyZbarError
# ----> 7 from .wrapper import (
#       8     zbar_image_scanner_set_config,
#       9     zbar_image_scanner_create, zbar_image_scanner_destroy,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in <module>
#     149
#     150
# --> 151 zbar_version = zbar_function(
#     152     'zbar_version',
#     153     c_int,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in zbar_function(fname, restype, *args)
# ...

# %%
import cv2
os.environ['PATH'] += r"C:\Users\bokke\ZBar"
import pyzbar.pyzbar as pyzbar

# Load the image
image = cv2.imread(r"C:\Users\bokke\ocr-extract-table-from-image-python\image\IMG-20240413-WA0008.jpg")  # Use raw string (r'') to avoid escaping backslashes

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect the QR code
qr_codes = pyzbar.decode(gray_image)

# Print the decoded data
for qr_code in qr_codes:
    print('Decoded data:', qr_code.data.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-55-b33e3296045d> in <cell line: 3>()
#       1 import cv2
#       2 os.environ['PATH'] += r"C:\Users\bokke\ZBar"
# ----> 3 import pyzbar.pyzbar as pyzbar
#       4
#       5 # Load the image
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/pyzbar.py in <module>
#       5 from .locations import bounding_box, convex_hull, Point, Rect
#       6 from .pyzbar_error import PyZbarError
# ----> 7 from .wrapper import (
#       8     zbar_image_scanner_set_config,
#       9     zbar_image_scanner_create, zbar_image_scanner_destroy,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in <module>
#     149
#     150
# --> 151 zbar_version = zbar_function(
#     152     'zbar_version',
#     153     c_int,
#
# /usr/local/lib/python3.10/dist-packages/pyzbar/wrapper.py in zbar_function(fname, restype, *args)
# ...

# %%
cv2.imshow('Image', image)
cv2.waitKey(0)  # Wait for a key press to close the window
cv2.destroyAllWindows()

# %%
json_output = result2.export()
json_output
# Out:
# {'pages': [{'page_idx': 0,
#    'dimensions': (1146, 898),
#    'orientation': {'value': None, 'confidence': None},
#    'language': {'value': None, 'confidence': None},
#    'blocks': [{'geometry': ((0.4302094933184855, 0.0400390625),
#       (0.5685442476336303, 0.0546875)),
#      'lines': [{'geometry': ((0.4302094933184855, 0.0400390625),
#         (0.5685442476336303, 0.0546875)),
#        'words': [{'value': 'TAX',
#          'confidence': 0.9986928105354309,
#          'geometry': ((0.4302094933184855, 0.0400390625),
#           (0.47507481904231624, 0.0546875)),
#          'crop_orientation': {'value': 0, 'confidence': None}},
#         {'value': 'INVOICE',
#          'confidence': 0.9385964274406433,
#          'geometry': ((0.4813061142817372, 0.0419921875),
#           (0.5685442476336303, 0.0537109375)),
#          'crop_orientation': {'value': 0, 'confidence': None}}]}],
#      'artefacts': []},
#     {'geometry': ((0.733050441954343, 0.0400390625),
# ...

# %%
from doctr.io import DocumentFile
from doctr.models import kie_predictor

# Model
model = kie_predictor(det_arch='db_resnet50', reco_arch='crnn_vgg16_bn', pretrained=True)
# PDF
#doc = DocumentFile.from_pdf("path/to/your/doc.pdf")
# Analyze
result_1=model(hand_written)
result_2 = model(tax_invoice)

# %%
predictions1 = result_1.pages[0].predictions
predictions2 = result_2.pages[0].predictions

# %%
for class_name in predictions1.keys():
    list_predictions1 = predictions1[class_name]
    for prediction_1 in list_predictions1:

      print(f"Prediction for {'MEDICAL'}: {prediction_1}")
# Out:
# Prediction for MEDICAL: Prediction(value='MEDICAL', confidence=0.85, bounding_box=((0.310510947951505, 0.0830078125), (0.4726039924749164, 0.107421875)))
# Prediction for MEDICAL: Prediction(value='BILL', confidence=1.0, bounding_box=((0.485160495923913, 0.0830078125), (0.5662070181856187, 0.109375)))
# Prediction for MEDICAL: Prediction(value='RECEIPT', confidence=0.98, bounding_box=((0.5776220213210702, 0.083984375), (0.7340075642767558, 0.1083984375)))
# Prediction for MEDICAL: Prediction(value='Number:', confidence=0.9, bounding_box=((0.689489052048495, 0.1708984375), (0.7785260765050167, 0.1923828125)))
# Prediction for MEDICAL: Prediction(value='Receipt', confidence=0.97, bounding_box=((0.6084425297867893, 0.1708984375), (0.6872060514214047, 0.193359375)))
# Prediction for MEDICAL: Prediction(value='#14586', confidence=0.96, bounding_box=((0.7933655805811037, 0.1484375), (0.9383361204013378, 0.1953125)))
# ...

# %%
for class_name in predictions2.keys():
    list_predictions2 = predictions2[class_name]
    for prediction_2 in list_predictions2:
      pass
        #print(f"Prediction for {class_name}: {prediction}")

# %%
# for invoice
print(f"Prediction for {'hundred'}: {prediction1}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-6a06c45f41e5> in <cell line: 2>()
#       1 # for invoice
# ----> 2 print(f"Prediction for {'hundred'}: {prediction1}")
#
# NameError: name 'prediction1' is not defined

# %%
list_predictions1
# Out:
# [Prediction(value='MEDICAL', confidence=0.85, bounding_box=((0.310510947951505, 0.0830078125), (0.4726039924749164, 0.107421875))),
#  Prediction(value='BILL', confidence=1.0, bounding_box=((0.485160495923913, 0.0830078125), (0.5662070181856187, 0.109375))),
#  Prediction(value='RECEIPT', confidence=0.98, bounding_box=((0.5776220213210702, 0.083984375), (0.7340075642767558, 0.1083984375))),
#  Prediction(value='Number:', confidence=0.9, bounding_box=((0.689489052048495, 0.1708984375), (0.7785260765050167, 0.1923828125))),
#  Prediction(value='Receipt', confidence=0.97, bounding_box=((0.6084425297867893, 0.1708984375), (0.6872060514214047, 0.193359375))),
#  Prediction(value='#14586', confidence=0.96, bounding_box=((0.7933655805811037, 0.1484375), (0.9383361204013378, 0.1953125))),
#  Prediction(value='Date:', confidence=1.0, bounding_box=((0.720309560514214, 0.1953125), (0.7785260765050167, 0.21875))),
# ...

# %%
pre_=DocumentFile.from_images('/content/pre_version.png')
result=model(pre_)

# %%
result.show()

# %%
synthetic_pages = result.synthesize()

# Print image array shape and datatype
print(synthetic_pages[0].shape, synthetic_pages[0].dtype)

# Display the image using imshow to verify content
plt.figure(figsize=(10, 20))
plt.imshow(synthetic_pages[0])
plt.axis('off')

plt.show()
# Out:
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# (1061, 750, 3) int32
